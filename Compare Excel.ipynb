# %%
import pandas as pd

df1 = pd.read_excel("OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx");
df2 = pd.read_excel("OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2ap.xlsx");

difference = df1[df1!=df2]
print(difference)
# Out:
#      Run Number      Run Start Time        Run End Time  Run Duration  \
# NaN         NaN 2018-01-09 09:42:09 2018-01-09 11:03:48         81.65
#
#     Model Start Date Model End Date  Model Duration  Availability  \
# NaN              NaT            NaT             NaN           NaN
#
#      Canisters Produced  LCP Batches  LCP Batches w/ Recycle  \
# NaN                 NaN          NaN                     NaN
#
#      Average Recycle Vol.  Sup DEP-1 Average Volume  Sup DEP-1 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-1 Time @ Max  Sup DEP-2 Average Volume  Sup DEP-2 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-2 Time @ Max  Sup DEP-3 Max Volume
# NaN                   NaN                   NaN

# %%
print (difference)
# Out:
#      Run Number      Run Start Time        Run End Time  Run Duration  \
# NaN         NaN 2018-01-09 09:42:09 2018-01-09 11:03:48         81.65
#
#     Model Start Date Model End Date  Model Duration  Availability  \
# NaN              NaT            NaT             NaN           NaN
#
#      Canisters Produced  LCP Batches  LCP Batches w/ Recycle  \
# NaN                 NaN          NaN                     NaN
#
#      Average Recycle Vol.  Sup DEP-1 Average Volume  Sup DEP-1 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-1 Time @ Max  Sup DEP-2 Average Volume  Sup DEP-2 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-2 Time @ Max  Sup DEP-3 Max Volume
# NaN                   NaN                   NaN

# %%
difference
# Out:
#      Run Number      Run Start Time        Run End Time  Run Duration  \
# NaN         NaN 2018-01-09 09:42:09 2018-01-09 11:03:48         81.65
#
#     Model Start Date Model End Date  Model Duration  Availability  \
# NaN              NaT            NaT             NaN           NaN
#
#      Canisters Produced  LCP Batches  LCP Batches w/ Recycle  \
# NaN                 NaN          NaN                     NaN
#
#      Average Recycle Vol.  Sup DEP-1 Average Volume  Sup DEP-1 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-1 Time @ Max  Sup DEP-2 Average Volume  Sup DEP-2 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-2 Time @ Max  Sup DEP-3 Max Volume
# NaN                   NaN                   NaN

# %%
df3 = pd.read_excel("OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2mod.xlsx");
diff2 = df1[df1!=df2]
diff2
# Out:
#      Run Number      Run Start Time        Run End Time  Run Duration  \
# NaN         NaN 2018-01-09 09:42:09 2018-01-09 11:03:48         81.65
#
#     Model Start Date Model End Date  Model Duration  Availability  \
# NaN              NaT            NaT             NaN           NaN
#
#      Canisters Produced  LCP Batches  LCP Batches w/ Recycle  \
# NaN                 NaN          NaN                     NaN
#
#      Average Recycle Vol.  Sup DEP-1 Average Volume  Sup DEP-1 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-1 Time @ Max  Sup DEP-2 Average Volume  Sup DEP-2 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-2 Time @ Max  Sup DEP-3 Max Volume
# NaN                   NaN                   NaN

# %%
df1bd = pd.read_excel("OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx", "BD Log");
df3bd = pd.read_excel("OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2mod.xlsx", "BD Log");
diffbd = df1bd[df1bd!=df3bd]
diffbd
# Out:
#      Run_Number  BD_Number  Component_ID System Description  \
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# ...

# %%
print (diffbd)
# Out:
#      Run_Number  BD_Number  Component_ID System Description  \
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# NaN         NaN        NaN           NaN    NaN         NaN
# ...

# %%
from itertools import zip_longest
import xlrd

rb1 = xlrd.open_workbook('./compareFiles/OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx')
rb2 = xlrd.open_workbook('./compareFiles/OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2mod.xlsx')

sheet1 = rb1.sheet_by_index(1)
sheet2 = rb2.sheet_by_index(1)

for rownum in range(max(sheet1.nrows, sheet2.nrows)):
    if rownum < sheet1.nrows:
        row_rb1 = sheet1.row_values(rownum)
        row_rb2 = sheet2.row_values(rownum)

        for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
            if c1 != c2:
                print ("Sheet {} Row {} Col {} - {} != {}".format(sheet1.name, rownum+1, colnum+1, c1, c2))
    else:
        print ("Sheet {} Row {} missing".format(sheet1.name, rownum+1))
# Out:
# Sheet BD Log Row 5 Col 19 -  != bogus data inserted only into this cell for testing purposes

# %%
rb3 = xlrd.open_workbook('OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx')

sheet1 = rb3.sheet_by_index(1)
print (sheet1.name)
# Out:
# BD Log

# %%
sheet1 = rb1.sheet_by_index(2)
sheet2 = rb2.sheet_by_index(2)

for rownum in range(max(sheet1.nrows, sheet2.nrows)):
    if rownum < sheet1.nrows:
        row_rb1 = sheet1.row_values(rownum)
        row_rb2 = sheet2.row_values(rownum)

        for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
            if c1 != c2:
                print ("Sheet {} Row {} Col {} - {} != {}".format(sheet1.name, rownum+1, colnum+1, c1, c2))
    else:
        print ("Sheet {} Row {} missing".format(sheet1.name, rownum+1))

# %%
sheet1 = rb1.sheet_by_index(0)
sheet2 = rb2.sheet_by_index(0)

for rownum in range(max(sheet1.nrows, sheet2.nrows)):
    if rownum < sheet1.nrows:
        row_rb1 = sheet1.row_values(rownum)
        row_rb2 = sheet2.row_values(rownum)

        for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
            if c1 != c2:
                print ("Sheet {} Row {} Col {} - {} != {}".format(sheet1.name, rownum+1, colnum+1, c1, c2))
    else:
        print ("Sheet {} Row {} missing".format(sheet1.name, rownum+1))
# Out:
# Sheet Summary Row 2 Col 3 - 43109.404270833336 != 43111.511400462965
# Sheet Summary Row 2 Col 4 - 43109.46097222222 != 43111.568819444445
# Sheet Summary Row 2 Col 5 - 81.6499999971129 != 82.68333333078772

# %%
sheet1 = rb1.sheet_by_index(1)
sheet2 = rb2.sheet_by_index(1)

for rownum in range(max(sheet1.nrows, sheet2.nrows)):
    if rownum < sheet1.nrows:
        row_rb1 = sheet1.row_values(rownum)
        row_rb2 = sheet2.row_values(rownum)

        for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
            if c1 != c2:
                print ("Sheet {} Row {} Col {} - {} != {}".format(sheet1.name, rownum+1, colnum+1, c1, c2))
    else:
        print ("Sheet {} Row {} missing".format(sheet1.name, rownum+1))
# Out:
# Sheet BD Log Row 5 Col 19 -  != bogus data inserted only into this cell for testing purposes

# %%
diff2
# Out:
#      Run Number      Run Start Time        Run End Time  Run Duration  \
# NaN         NaN 2018-01-09 09:42:09 2018-01-09 11:03:48         81.65
#
#     Model Start Date Model End Date  Model Duration  Availability  \
# NaN              NaT            NaT             NaN           NaN
#
#      Canisters Produced  LCP Batches  LCP Batches w/ Recycle  \
# NaN                 NaN          NaN                     NaN
#
#      Average Recycle Vol.  Sup DEP-1 Average Volume  Sup DEP-1 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-1 Time @ Max  Sup DEP-2 Average Volume  Sup DEP-2 Max Volume  \
# NaN                   NaN                       NaN                   NaN
#
#      Sup DEP-2 Time @ Max  Sup DEP-3 Max Volume
# NaN                   NaN                   NaN

# %%
List = open('.\compareFiles\compareList.txt').read().splitlines()
List
# Out:
# ['OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2ap.xlsx',
#  'OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2mod.xlsx']

# %%
print (List[0])
# Out:
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2ap.xlsx

# %%
print (List[0].split()[0])
print (List[0].split()[])
# Out:
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2ap.xlsx

# %%
List = open('.\compareFiles\compareList.txt').read().splitlines()
for line in List:
    for filename in line.split(" -- "):
        print (filename)
# Out:
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2ap.xlsx
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2pp.xlsx
# OR_LAWVIT_Output_MRR-58045_Adjusted_1_12_A-2mod.xlsx

# %%
def Compare(file1, file2):
    from itertools import zip_longest
    import xlrd

    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = worksheet
        sheet2 = worksheet

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        print ("{} Sheet {} Row {} Col {} - {} != {}".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                print ("{} Sheet {} Row {} missing".format(file1,sheet1.name, rownum+1))
    return;


for line in List:
    file1 = line.split(" -- ")[0]
    file1 = "./compareFiles/" + file1
    file2 = line.split(" -- ")[1]
    file2 = "./compareFiles/" + file2
    Compare(file1, file2)

# %%
def Compare(file1, file2):
    from itertools import zip_longest
    import xlrd

    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = rb1.sheet_by_name(worksheet.name)
        sheet2 = rb2.sheet_by_name(worksheet.name)

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        #print ("{} Sheet {} Row {} Col {} - {} != {}".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                print ("{} Sheet {} Row {} missing".format(file1,sheet1.name, rownum+1))
    return;

path = ".\\compareFiles\\"
List = open(path + "compareList.txt").read().splitlines()

for line in List:
    file1 = path + line.split(" -- ")[0]
    file2 = path + line.split(" -- ")[1]
    Compare(file1, file2)
# Out:
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet Overview Row 4 Col 9 - 14.0 != 15.0
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet Overview Row 6 Col 3 - Monday, October 31, 2016 12:43:25 PM != Monday, October 31, 2016 11:32:11 AM
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet Overview Row 7 Col 3 - Monday, October 31, 2016 12:46:05 PM != Monday, October 31, 2016 11:35:21 AM
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet Overview Row 7 Col 9 - 0h 2m 40s != 0h 3m 10s
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet SSW1 Row 969 Col 10 - 9/13/2027 17:38:06 != 9/13/2027 17:38:07
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet SSW1 Row 969 Col 11 - 9/13/2027 17:38:06 != 9/13/2027 17:38:07
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx Sheet Transfers Row 49 Col 2 - 49.85689488870412 != 49.85689488875505
# ...

# %%
import _thread

def Compare(file1, file2):
    from itertools import zip_longest
    import xlrd

    print("Beginning Compare")
    
    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = rb1.sheet_by_name(worksheet.name)
        sheet2 = rb2.sheet_by_name(worksheet.name)

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        print ("{} Sheet {} Row {} Col {} - {} != {}".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                print ("{} Sheet {} Row {} missing".format(file1,sheet1.name, rownum+1))
    return;

path = ".\\compareFiles\\"
List = open(path + "compareList.txt").read().splitlines()

for line in List:
    file1 = path + line.split(" -- ")[0]
    file2 = path + line.split(" -- ")[1]
    print("Starting thread")
    _thread.start_new_thread(Compare, (file1, file2))
# Out:
# Starting thread
# Beginning CompareBeginning CompareBeginning CompareBeginning CompareBeginning CompareStarting thread
#
#
#
#
#
# Starting thread
# Starting thread
# Starting thread

# %%
import threading

def Compare(file1, file2):
    from itertools import zip_longest
    import xlrd

    #print("Beginning Comparing against " + file1 + "\n")
    
    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = rb1.sheet_by_name(worksheet.name)
        sheet2 = rb2.sheet_by_name(worksheet.name)

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        c1 = c1
                        print ("{} Sheet {} Row {} Col {} - {} != {}".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                print ("{} Sheet {} Row {} missing".format(file1,sheet1.name, rownum+1))
    #print(file1 + " comparison finished")
    return;

exitFlag = 0

class myThread (threading.Thread):
    def __init__(self, threadID, name, counter, args):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.counter = counter
        self.args = args
    def run(self):
        #print ("Starting " + self.name + " with file " + self.args[0] + "\n")
        Compare(self.args[0], self.args[1])
        #print ("Exiting " + self.name)

path = ".\\compareFiles\\"
List = open(path + "compareList.txt").read().splitlines()
i = 0
file = []
thread = []

for line in List:
    i = i + 1
    file.append (path + line.split(" -- ")[0])
    file.append (path + line.split(" -- ")[1])
    #print ("File1: " + file[0] + "\n")
    thread.append  (myThread(i, "thread" + str(i), i, file))
    thread[i - 1].start()
    file.pop()
    file.pop()
    #thread[i - 1].join()
# Out:
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet Overview Row 4 Col 9 - 14.0 != 15.0
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet Overview Row 5 Col 3 - 42 != OR_IDF_MRR_58056_Input_12-2-2015.xlsx
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet Overview Row 6 Col 3 - Monday, October 31, 2016 12:49:39 PM != Monday, October 31, 2016 11:39:14 AM
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet Overview Row 7 Col 3 - Monday, October 31, 2016 12:52:09 PM != Monday, October 31, 2016 11:42:31 AM
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet Overview Row 7 Col 9 - 0h 2m 30s != 0h 3m 17s
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet SSW1 Row 6883 Col 10 - 12/19/2030 21:57:26 != 12/19/2030 21:57:27
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx Sheet SSW1 Row 6883 Col 11 - 12/19/2030 21:57:26 != 12/19/2030 21:57:27
# ...

# %%
import threading
import datetime

start = datetime.datetime.now()
print(start)

def Compare(file1, file2, output):
    from itertools import zip_longest
    import xlrd

    print("Beginning Comparing against " + file1 + "\n")
    
    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = rb1.sheet_by_name(worksheet.name)
        sheet2 = rb2.sheet_by_name(worksheet.name)

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        c1 = c1
                        output.write ("{}; Sheet {}; Row {}; Col {}; -; {}; !=; {}\n".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                output.write ("{}; Sheet {}; Row {}; missing\n".format(file1,sheet1.name, rownum+1))
    print(file1 + " comparison finished")
    end = datetime.datetime.now()
    print(end)
    return;

exitFlag = 0

class myThread (threading.Thread):
    def __init__(self, threadID, name, counter, args, output):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.counter = counter
        self.args = args
    def run(self):
        Compare(self.args[0], self.args[1], output)

path = ".\\compareFiles\\"
List = open(path + "compareList.txt").read().splitlines()
i = 0
file = []
thread = []
output = open('results.txt', 'w')

for line in List:
    i = i + 1
    file.append (path + line.split(" -- ")[0])
    file.append (path + line.split(" -- ")[1])
    thread.append  (myThread(i, "thread" + str(i), i, file, output))
    thread[i - 1].start()
    file.pop()
    file.pop()
# Out:
# 2018-02-05 14:12:52.480550
# Beginning Comparing against .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx
#
# Beginning Comparing against .\compareFiles\OR_IDF_MRR_58056_Output_1_14_1.xlsx
#
# Beginning Comparing against .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx
# Beginning Comparing against .\compareFiles\OR_IDF_MRR_58056_Output_1_14_3.xlsx
# Beginning Comparing against .\compareFiles\OR_IDF_MRR_58056_Output_1_14_4.xlsx
#
#
#
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_2.xlsx comparison finished
# 2018-02-05 14:14:40.439161
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_1.xlsx comparison finished
# 2018-02-05 14:14:45.037554
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_0.xlsx comparison finished
# 2018-02-05 14:14:45.912270
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_3.xlsx comparison finished
# 2018-02-05 14:14:54.774287
# .\compareFiles\OR_IDF_MRR_58056_Output_1_14_4.xlsx comparison finished
# 2018-02-05 14:14:58.620253

# %%
import threading
import datetime

start = datetime.datetime.now()
print(start)

def Compare(file1, file2, output):
    from itertools import zip_longest
    import xlrd

    print("Beginning Comparing against " + file1 + "\n")
    
    rb1 = xlrd.open_workbook(file1)
    rb2 = xlrd.open_workbook(file2)
    
    for worksheet in rb1.sheets():
        sheet1 = rb1.sheet_by_name(worksheet.name)
        sheet2 = rb2.sheet_by_name(worksheet.name)

        for rownum in range(max(sheet1.nrows, sheet2.nrows)):
            if rownum < sheet1.nrows:
                row_rb1 = sheet1.row_values(rownum)
                row_rb2 = sheet2.row_values(rownum)

                for colnum, (c1, c2) in enumerate(zip_longest(row_rb1, row_rb2)):
                    if c1 != c2:
                        c1 = c1
                        output.write ("{}; Sheet {}; Row {}; Col {}; -; {}; !=; {}\n".format(file1, sheet1.name, rownum+1, colnum+1, c1, c2))
            else:
                output.write ("{}; Sheet {}; Row {}; missing\n".format(file1,sheet1.name, rownum+1))
    print(file1 + " comparison finished")
    end = datetime.datetime.now()
    print(end)
    return;

exitFlag = 0

class myThread (threading.Thread):
    def __init__(self, threadID, name, counter, args, output):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.counter = counter
        self.args = args
    def run(self):
        Compare(self.args[0], self.args[1], output)

path = ".\\compareFiles\\"
List = open(path + "compareList.txt").read().splitlines()
i = 0
file = []
thread = []
output = open('results.txt', 'w')

for line in List:
    i = i + 1
    file.append (path + line.split(" -- ")[0])
    file.append (path + line.split(" -- ")[1])
    thread.append  (myThread(i, "thread" + str(i), i, file, output))
    thread[i - 1].start()
    file.pop()
    file.pop()
# Out:
# 2018-02-05 14:22:05.559763
# Beginning Comparing against .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_1_A-1a.xlsx
# Beginning Comparing against .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_1_A-2a.xlsx
#
#
# Beginning Comparing against .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_2_A-1a.xlsx
# Beginning Comparing against .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_2_A-2a.xlsx
#
#
# .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_2_A-1a.xlsx comparison finished.\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_2_A-1a.xlsx comparison finished
# 2018-02-05 15:22:02.853830
#
# 2018-02-05 15:22:02.856337
# .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_1_A-1a.xlsx comparison finished
# 2018-02-05 15:23:25.797873
# .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_1_A-1a.xlsx comparison finished
# 2018-02-05 15:24:12.345366
# .\compareFiles\OR_LAWVIT_Output_MRR-58045_Adjusted_1_1_A-1a.xlsx comparison finished
# 2018-02-05 15:27:34.080002
# ...
